# %% [markdown]
# #### MongoDB Code Lab

# %%
# %env HOST = mongodb+srv://monjen.ofabgfp.mongodb.net/sample_weatherdata
# %env USER = monicapham019
# %env PW = wMmBk1WPwzENxzcz
# Out:
# env: HOST=mongodb+srv://monjen.ofabgfp.mongodb.net/sample_weatherdata
# env: USER=monicapham019
# env: PW=wMmBk1WPwzENxzcz

# %%
CONNECT ="/usr/bin/mongosh $HOST -u $USER -p $PW"

# %%
# !{CONNECT}
# Out:
# Current Mongosh Log ID:	653b0b06de163637d7f8490f
# Connecting to:		mongodb+srv://<credentials>@monjen.ofabgfp.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Atlas atlas-zirspp-shard-0 [primary] sample_weatherdata>
# (To exit, press Ctrl+C again or Ctrl+D or type .exit)
# Atlas atlas-zirspp-shard-0 [primary] sample_weatherdata>

# %%
# !{CONNECT} --eval "show collections"
# Out:
# Current Mongosh Log ID:	653b0b0b16019e52968c6a12
# Connecting to:		mongodb+srv://<credentials>@monjen.ofabgfp.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  data

# %%
# !{CONNECT} --eval "db.data.findOne()"
# Out:
# Current Mongosh Log ID:	653b0b0ce7ef50bd4a396228
# Connecting to:		mongodb+srv://<credentials>@monjen.ofabgfp.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  {
#   _id: ObjectId("5553a998e4b02cf7151190bd"),
#   st: 'x+59800-029700',
#   ts: ISODate("1984-03-05T15:00:00.000Z"),
#   position: { type: 'Point', coordinates: [ -29.7, 59.8 ] },
#   elevation: 9999,
#   callLetters: 'TFWB',
#   qualityControlProcess: 'V020',
#   dataSource: '4',
#   type: 'FM-13',
#   airTemperature: { value: 3.1, quality: '1' },
#   dewPoint: { value: 999.9, quality: '9' },
#   pressure: { value: 1019, quality: '1' },
#   wind: {
#     direction: { angle: 250, quality: '1' },
#     type: 'N',
#     speed: { rate: 15.4, quality: '1' }
#   },
#   visibility: {
#     distance: { value: 10000, quality: '1' },
#     variability: { value: 'N', quality: '9' }
#   },
#   skyCondition: {
# ...

# %% [markdown]
# ## Begin Project 6 Work:

# %% [markdown]
# #### Run the project 6 queries for MongoDB, which is 10 queries:

# %%
# !{CONNECT} -f /home/jupyter/project6_queries.js
# Out:
# Current Mongosh Log ID:	653b0b0d913aabb9578a9dce
# Connecting to:		mongodb+srv://<credentials>@monjen.ofabgfp.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Loading file: /home/jupyter/project6_queries.js
# ****************************************************************
# 0) Number of documents in the data collection from sample_weatherdata
# 10000
# ****************************************************************
# 1) Find documents with Air Temperature between 3.0 and 4.0, Visibility Distance = 10000, 'position.type' is 'Point', sorted by timestamp in ascending order
# [
#   {
#     ts: ISODate("1984-03-05T15:00:00.000Z"),
#     position: {
#       type: 'Point'
#     },
#     airTemperature: {
#       value: 3.1
#     },
#     visibility: {
#       distance: {
#         value: 10000
#       }
#     }
#   },
#   {
# ...

# %% [markdown]
# ## Optional Extra Credit: 10 mutating operations Queries

# %%
# !{CONNECT} -f /home/jupyter/exam1_extra_credit.js
# Out:
# Current Mongosh Log ID:	653b0b829b759134cea53993
# Connecting to:		mongodb+srv://<credentials>@monjen.ofabgfp.mongodb.net/sample_weatherdata?appName=mongosh+2.0.2
# Using MongoDB:		6.0.11
# Using Mongosh:		2.0.2
#
# For mongosh info see: https://docs.mongodb.com/mongodb-shell/
#
#  Loading file: /home/jupyter/exam1_extra_credit.js
# ****************************************************************
# 1) Inserting a document with insertOne():
# {
#   acknowledged: true,
#   insertedId: ObjectId("1433a948e4b01cf7256990bd")
# }
# ****************************************************************
# 2) Insert multiple documents with insertMany(1st set):
# {
#   acknowledged: true,
#   insertedIds: {
#     '0': ObjectId("653b0b839b759134cea53994"),
#     '1': ObjectId("653b0b839b759134cea53995")
#   }
# }
# ****************************************************************
# 3) Insert multiple documents with insertMany(2nd set):
# {
#   acknowledged: true,
#   insertedIds: {
# ...
